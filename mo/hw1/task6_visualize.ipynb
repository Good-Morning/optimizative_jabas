# %%
import task6 as t6

# %%
def paraboloid(x, y):
    return (x - 3) ** 2 + y ** 2

# %%
t6.draw_contour(t6.rosenbrock)
# Out:
# found min=[0.97004977 0.94104178] by Dichotomy, iterations=7
# found min=[-3.76712189 14.19567621] by Gold section, iterations=50
# found min=[-10.68063962 114.08394693] by Fibonacci, iterations=50
# found min=[-3.19284826 10.1922981 ] by Line search, iterations=50
# real min=(0.9859719438877761, 0.9719438877755513)

# %%
t6.draw_contour(paraboloid)
# Out:
# found min=[2.99944398e+00 1.66806028e-03] by Dichotomy, iterations=1
# found min=[3.00129121 0.00322803] by Gold section, iterations=1
# found min=[3.00488267 0.00683574] by Fibonacci, iterations=50
# found min=[3.00002840e+00 3.19484342e-05] by Line search, iterations=3
# real min=(3.006012024048095, 0.010020040080160442)
